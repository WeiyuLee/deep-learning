# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

# Threshold t
threshold = 1e-5

word_counts = Counter(int_words)
total_count = len(int_words)

# Get the freq. of each word
freqs = {word: count/total_count for word, count in word_counts.items()}

# Discard each word given the probablility
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

# Discard the words by going through int_words
# random.random() returns number between 0 and 1
train_words = [word for word in int_words if random.random() > (p_drop[word])]

# %%
type(train_words)
# Out:
# list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' 
    Get a list of words in a window around an index. 
    words: all the words in the current batch
    idx: current word's index
    window_size: windows's size
    '''
    
    # Return random integers from low (inclusive) to high (exclusive).
    R = np.random.randint(1, window_size+1)
    
    # Make the window
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    
    # Apply the window
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        # for the begining of a new batch, reset x, y.
        x, y = [], []
        
        # extract this batch's words
        batch = words[idx:idx+batch_size]
        
        # get each word's target window
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# **The idea here is to train the hidden layer weight matrix to find efficient representations for our words.** We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        # get_batches() will go through all the batches
        batches = get_batches(train_words, batch_size, window_size)
        
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6441 0.0534 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6234 0.0513 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4741 0.0511 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6256 0.0513 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5052 0.0509 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5496 0.0512 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5435 0.0510 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5246 0.0512 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4716 0.0506 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4368 0.0505 sec/batch
# Nearest to states: malay, resurrection, ricci, civilization, wabe, venerable, palaeologus, prev,
# Nearest to will: moldova, nabonidus, headquarters, germain, orations, orthopedic, notting, rajiv,
# Nearest to united: parole, aa, vocation, sothoth, custom, yugoslavian, ranatunga, celebrities,
# Nearest to d: luba, pilgrimage, feathered, hydroxy, ricci, chaeronea, ennius, libels,
# Nearest to system: tydings, oau, herald, newfoundland, patently, thane, archon, collin,
# Nearest to who: stralsund, adleman, precursor, graphics, impermeable, philharmonic, subjective, ambushed,
# Nearest to was: sightseeing, gretchen, abstention, aerospace, filmmaking, exclave, authorizing, baldassare,
# Nearest to more: unintentional, volo, archivers, vaz, phrygia, utilizing, illa, strung,
# Nearest to stage: sierra, prone, hollies, occupy, warbeck, browser, skimmed, undertook,
# Nearest to shows: abrahams, shopping, transporting, callet, membership, ride, oxbridge, carinae,
# Nearest to older: interment, ed, voting, osce, jour, preposition, carmilla, schumacher,
# Nearest to defense: hugo, mystics, tracer, almond, citizen, dynasties, flaherty, rushmore,
# Nearest to grand: acton, mut, appraisals, coanda, mande, streamlined, uyghur, iturbide,
# Nearest to ocean: lorenz, jona, ears, cauca, secam, noncombatant, taipa, escobar,
# Nearest to test: liverpudlians, cellspacing, westley, carly, revues, genealogists, vitangelo, osh,
# Nearest to pressure: smithers, scholz, impiety, tigran, liutprand, vegetation, sampletranslation, dividend,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4857 0.0514 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3881 0.0501 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3477 0.0502 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2416 0.0503 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1660 0.0499 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1778 0.0499 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0817 0.0494 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0826 0.0499 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0067 0.0499 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0041 0.0497 sec/batch
# Nearest to states: reasonable, resurrection, malay, rate, home, civilization, saint, venerable,
# Nearest to will: headquarters, moldova, dtt, turning, nabonidus, requiring, include, deity,
# Nearest to united: custom, parole, aa, birthday, sothoth, electoral, shapes, free,
# Nearest to d: luba, pilgrimage, ricci, hydroxy, feathered, fiji, pet, influential,
# Nearest to system: herald, tydings, newfoundland, doug, assertion, latino, regulate, dairy,
# Nearest to who: stralsund, precursor, adleman, graphics, subjective, treated, philharmonic, gays,
# Nearest to was: sightseeing, gretchen, places, controversies, abstention, analysis, signature, aerospace,
# Nearest to more: volo, unintentional, strung, utilizing, exports, curriculum, going, produces,
# Nearest to stage: sierra, prone, occupy, hard, browser, warbeck, undertook, upright,
# Nearest to shows: membership, ride, carinae, abrahams, transporting, neck, luc, shopping,
# Nearest to older: interment, ed, voting, video, reaffirmed, methodical, preposition, functioning,
# Nearest to defense: counter, hugo, citizen, mystics, almond, hole, character, tracer,
# Nearest to grand: acton, coanda, mut, appraisals, mande, iturbide, streamlined, malcolm,
# Nearest to ocean: lorenz, unreliable, secam, ears, noncombatant, jona, stabilize, murphy,
# Nearest to test: westley, genealogists, liverpudlians, netlist, revues, carly, reunification, compromised,
# Nearest to pressure: vegetation, achieve, scholz, allocation, sampletranslation, smithers, impiety, longer,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9371 0.0507 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9318 0.0498 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8908 0.0498 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8522 0.0497 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8276 0.0499 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8068 0.0498 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7989 0.0497 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8048 0.0500 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7715 0.0500 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7850 0.0500 sec/batch
# Nearest to states: malay, ricci, venerable, spreadsheet, reasonable, resurrection, civilization, rate,
# Nearest to will: gags, interview, incredibly, dtt, deity, headquarters, towns, digit,
# Nearest to united: parole, custom, electoral, aa, percent, birthday, guessed, yugoslavian,
# Nearest to d: luba, pilgrimage, ricci, hydroxy, feathered, relentless, fiji, chaeronea,
# Nearest to system: herald, tydings, assertion, regulate, newfoundland, slideshow, latino, hydro,
# Nearest to who: stralsund, precursor, philharmonic, adleman, gays, ombudsman, subjective, treated,
# Nearest to was: sightseeing, aerospace, filmmaking, gretchen, isidor, poses, controversies, vigorously,
# Nearest to more: unintentional, volo, strung, utilizing, curriculum, stiff, addressed, parodies,
# Nearest to stage: sierra, occupy, prone, discontent, warbeck, upright, hard, skimmed,
# Nearest to shows: transporting, membership, shopping, ride, neck, abrahams, luc, suffrage,
# Nearest to older: interment, voting, ed, reaffirmed, methodical, jour, donuts, preposition,
# Nearest to defense: hugo, counter, citizen, mystics, hole, dynasties, almond, character,
# Nearest to grand: acton, coanda, nm, mut, malcolm, geo, jacobins, impressive,
# Nearest to ocean: unreliable, lorenz, ears, organisms, murphy, stabilize, legitimize, secam,
# Nearest to test: westley, genealogists, liverpudlians, netlist, reunification, carly, retainer, compromised,
# Nearest to pressure: allocation, vegetation, achieve, dividend, smithers, scholz, longer, geared,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7595 0.0502 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7489 0.0498 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7214 0.0495 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7110 0.0497 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7548 0.0495 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7006 0.0498 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6997 0.0498 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7105 0.0497 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6932 0.0496 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6696 0.0496 sec/batch
# Nearest to states: malay, suharto, papua, palaeologus, insurrections, neighbors, ricci, sunda,
# Nearest to will: dtt, gags, incredibly, homeostatic, notting, tail, interview, ramayana,
# Nearest to united: electoral, parole, custom, yugoslavian, vocation, surrey, birthday, celebrities,
# Nearest to d: luba, pilgrimage, ricci, relentless, hydroxy, american, earl, author,
# Nearest to system: tydings, herald, assertion, slideshow, hydro, regulate, latino, dorset,
# Nearest to who: philharmonic, stralsund, precursor, adleman, gays, impermeable, ombudsman, magistrate,
# Nearest to was: sightseeing, gretchen, aerospace, filmmaking, vigorously, pastimes, isidor, exclave,
# Nearest to more: unintentional, curriculum, illa, volo, addressed, utilizing, parodies, strung,
# Nearest to stage: sierra, occupy, warbeck, prone, discontent, skimmed, upright, hard,
# Nearest to shows: transporting, ride, abrahams, shopping, membership, luc, carinae, better,
# Nearest to older: interment, voting, reaffirmed, methodical, ed, undefeated, jour, donuts,
# Nearest to defense: hugo, counter, citizen, mystics, almond, dynasties, tracer, character,
# Nearest to grand: acton, mut, jacobins, coanda, geo, impressive, uyghur, malcolm,
# Nearest to ocean: unreliable, lorenz, legitimize, ears, secam, noncombatant, stabilize, organisms,
# Nearest to test: westley, liverpudlians, genealogists, revues, netlist, carly, elihu, parlay,
# Nearest to pressure: allocation, smithers, achieve, dividend, vegetation, elman, geared, harmonisation,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6819 0.0504 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6584 0.0496 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6176 0.0495 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6319 0.0497 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6418 0.0497 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6288 0.0493 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6108 0.0360 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5591 0.0497 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5026 0.0496 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5084 0.0494 sec/batch
# Nearest to states: malay, suharto, papua, insurrections, palaeologus, upheavals, moose, legislative,
# Nearest to will: gags, incredibly, dtt, thence, favorable, homeostatic, palaeolithic, synthesised,
# Nearest to united: electoral, parole, yugoslavian, custom, gower, surrey, vocation, mayors,
# Nearest to d: earl, author, american, politician, b, ricci, composer, luba,
# Nearest to system: tydings, assertion, herald, latino, millionaire, slideshow, oau, leiserson,
# Nearest to who: stralsund, philharmonic, adleman, gays, precursor, impermeable, clav, ombudsman,
# Nearest to was: sightseeing, gretchen, filmmaking, pastimes, aerospace, meanwhile, vigorously, exclave,
# Nearest to more: unintentional, volo, utilizing, strung, vaz, illa, understated, curriculum,
# Nearest to stage: sierra, upright, occupy, warbeck, discontent, takers, skimmed, prone,
# Nearest to shows: transporting, ride, shopping, abrahams, membership, carinae, better, die,
# Nearest to older: interment, voting, reaffirmed, methodical, undefeated, ed, average, jour,
# Nearest to defense: hugo, citizen, counter, mystics, almond, tracer, dynasties, lodovico,
# Nearest to grand: acton, jacobins, mut, malcolm, uyghur, coanda, geo, impressive,
# Nearest to ocean: unreliable, legitimize, lorenz, jona, noncombatant, secam, martha, palestrina,
# Nearest to test: genealogists, liverpudlians, westley, netlist, ziegfeld, retainer, carly, clementine,
# Nearest to pressure: allocation, smithers, dividend, achieve, vegetation, energy, elman, harmonisation,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4748 0.0503 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4957 0.0497 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4634 0.0497 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5222 0.0495 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4729 0.0496 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5067 0.0498 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4605 0.0496 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4055 0.0496 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4328 0.0493 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4113 0.0493 sec/batch
# Nearest to states: malay, papua, insurrections, suharto, constituency, legislative, upheavals, palaeologus,
# Nearest to will: homeostatic, gags, ergonomics, incredibly, dtt, thence, tail, notting,
# Nearest to united: electoral, parole, mayors, headquartered, custom, vocation, celebrities, schuman,
# Nearest to d: earl, ricci, luba, author, politician, seymour, hydroxy, sanderson,
# Nearest to system: tydings, assertion, slideshow, cost, monosaccharides, herald, use, latino,
# Nearest to who: stralsund, philharmonic, gays, adleman, famers, tarawa, witwatersrand, ombudsman,
# Nearest to was: sightseeing, pastimes, gretchen, meanwhile, filmmaking, dina, aerospace, tora,
# Nearest to more: unintentional, utilizing, vaz, volo, understated, strung, curriculum, flowers,
# Nearest to stage: sierra, warbeck, upright, discontent, occupy, skimmed, takers, farce,
# Nearest to shows: transporting, ride, better, carinae, abrahams, shopping, neck, membership,
# Nearest to older: interment, voting, average, reaffirmed, pipeline, donuts, router, methodical,
# Nearest to defense: counter, citizen, hugo, mystics, almond, tracer, stairways, contested,
# Nearest to grand: acton, jacobins, mut, uyghur, malcolm, impressive, raum, guile,
# Nearest to ocean: legitimize, unreliable, noncombatant, secam, scandinavia, jona, palestrina, kq,
# Nearest to test: liverpudlians, genealogists, westley, elihu, netlist, deviated, revues, ziegfeld,
# Nearest to pressure: allocation, smithers, achieve, dividend, energy, vegetation, elman, produces,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4520 0.0504 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4139 0.0495 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4115 0.0495 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3768 0.0495 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4058 0.0493 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4725 0.0494 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4074 0.0496 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3953 0.0494 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4082 0.0495 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3751 0.0497 sec/batch
# Nearest to states: malay, constituency, papua, suharto, insurrections, reservations, legislative, militaries,
# Nearest to will: homeostatic, ergonomics, gags, incredibly, favorable, nabonidus, synthesised, notting,
# Nearest to united: electoral, mayors, headquartered, parole, schuman, secession, caretaker, custom,
# Nearest to d: luba, ricci, seymour, earl, hydroxy, hone, yuri, sanderson,
# Nearest to system: tydings, slideshow, carmack, cost, monosaccharides, assertion, regulate, herald,
# Nearest to who: stralsund, philharmonic, clav, gays, adleman, child, carthage, tarawa,
# Nearest to was: sightseeing, pastimes, gretchen, dina, meanwhile, filmmaking, tora, filmmaker,
# Nearest to more: unintentional, curriculum, vaz, utilizing, strung, illa, simplification, tend,
# Nearest to stage: farce, skimmed, sierra, upright, redstone, warbeck, discontent, takers,
# Nearest to shows: transporting, ride, better, carinae, neck, abrahams, shopping, dendrites,
# Nearest to older: interment, average, voting, reaffirmed, ed, carmilla, router, age,
# Nearest to defense: counter, citizen, hugo, mystics, almond, tracer, contested, stairways,
# Nearest to grand: acton, malcolm, jacobins, uyghur, mut, raum, duc, impressive,
# Nearest to ocean: legitimize, noncombatant, meters, unreliable, mountains, kq, scandinavia, atlantic,
# Nearest to test: netlist, liverpudlians, genealogists, deviated, wedged, parlay, revues, elihu,
# Nearest to pressure: allocation, smithers, achieve, dividend, vegetation, energy, elman, harmonisation,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3755 0.0503 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3800 0.0496 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3424 0.0496 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3590 0.0497 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4264 0.0494 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4054 0.0496 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3871 0.0496 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3862 0.0495 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3187 0.0495 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3692 0.0495 sec/batch
# Nearest to states: suharto, malay, constituency, papua, militaries, insurrections, electoral, reservations,
# Nearest to will: homeostatic, ergonomics, incredibly, gags, nabonidus, byelorussia, troublesome, breaks,
# Nearest to united: electoral, mayors, parole, disputes, secession, schuman, headquartered, custom,
# Nearest to d: luba, ricci, yuri, seymour, leonhard, hone, sanderson, hydroxy,
# Nearest to system: tydings, slideshow, leeway, regulate, carmack, zed, patently, nerd,
# Nearest to who: stralsund, clav, adleman, philharmonic, gays, tarawa, ombudsman, child,
# Nearest to was: dina, sightseeing, meanwhile, pastimes, gretchen, tora, launching, maine,
# Nearest to more: unintentional, curriculum, vaz, illa, utilizing, simplification, tend, nouns,
# Nearest to stage: skimmed, farce, redstone, upright, discontent, sierra, concepci, hard,
# Nearest to shows: transporting, ride, better, carinae, neck, abrahams, dendrites, die,
# Nearest to older: interment, average, voting, age, reaffirmed, router, carmilla, ed,
# Nearest to defense: counter, citizen, hugo, mystics, almond, contested, stairways, salvador,
# Nearest to grand: uyghur, malcolm, acton, jacobins, mut, catcher, raum, guile,
# Nearest to ocean: meters, atlantic, legitimize, scandinavia, oceans, mountains, kq, noncombatant,
# Nearest to test: wedged, netlist, cellspacing, deviated, parlay, tout, monoclonal, liverpudlians,
# Nearest to pressure: smithers, allocation, achieve, dividend, vegetation, elman, magnets, harmonisation,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3621 0.0501 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2816 0.0497 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3795 0.0495 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3703 0.0495 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3904 0.0495 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2622 0.0493 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3387 0.0495 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3709 0.0493 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2261 0.0496 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2966 0.0496 sec/batch
# Nearest to states: suharto, malay, constituency, papua, militaries, insurrections, reservations, electoral,
# Nearest to will: homeostatic, ergonomics, gags, incredibly, clove, favorable, nabonidus, ramps,
# Nearest to united: electoral, mayors, parole, schuman, secession, armando, states, headquartered,
# Nearest to d: b, ricci, conductor, composer, luba, dramatist, seymour, earl,
# Nearest to system: tydings, leeway, slideshow, regulate, carausius, cost, carmack, zed,
# Nearest to who: stralsund, tarawa, philharmonic, adleman, clav, child, longterm, timecode,
# Nearest to was: dina, sightseeing, gretchen, meanwhile, maine, tora, gediminas, gingold,
# Nearest to more: unintentional, curriculum, tend, vaz, illa, utilizing, nouns, strung,
# Nearest to stage: farce, skimmed, concepci, sierra, takers, hard, upright, discontent,
# Nearest to shows: transporting, ride, better, carinae, neck, dendrites, beg, shopping,
# Nearest to older: average, age, interment, householder, voting, reaffirmed, households, ed,
# Nearest to defense: counter, citizen, hugo, contested, mystics, almond, stairways, tracer,
# Nearest to grand: uyghur, malcolm, acton, duc, jacobins, impressive, wintered, raum,
# Nearest to ocean: atlantic, meters, intelsat, scandinavia, oceans, farmland, seabirds, mountains,
# Nearest to test: cellspacing, wedged, parlay, monoclonal, deviated, netlist, tout, westley,
# Nearest to pressure: smithers, allocation, achieve, dividend, vegetation, elman, magnets, harmonisation,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2877 0.0502 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2917 0.0496 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3036 0.0219 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2174 0.0496 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2358 0.0498 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2058 0.0499 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2387 0.0495 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2141 0.0496 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2293 0.0495 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1892 0.0493 sec/batch
# Nearest to states: suharto, constituency, reservations, malay, militaries, insurrections, papua, united,
# Nearest to will: homeostatic, ergonomics, prosecution, ramps, gags, carbamazepine, requiring, humiliate,
# Nearest to united: electoral, mayors, parole, armando, secession, states, schuman, celebrities,
# Nearest to d: ricci, luba, leonhard, seymour, yuri, sanderson, b, zariski,
# Nearest to system: tydings, leeway, carausius, cost, desktop, paypal, slideshow, regulate,
# Nearest to who: tarawa, child, longterm, stralsund, philharmonic, magistrate, adleman, clav,
# Nearest to was: dina, sightseeing, gingold, meanwhile, gediminas, limousine, launching, cerialis,
# Nearest to more: unintentional, tend, curriculum, illa, vaz, utilizing, nouns, viceroyalty,
# Nearest to stage: upright, farce, skimmed, takers, redstone, sierra, apertures, meadow,
# Nearest to shows: transporting, ride, better, carinae, dendrites, neck, shopping, beg,
# Nearest to older: householder, average, age, households, females, household, median, interment,
# Nearest to defense: counter, citizen, contested, hugo, stairways, mystics, rushmore, tracer,
# Nearest to grand: uyghur, acton, jacobins, impressive, malcolm, raum, wintered, duc,
# Nearest to ocean: atlantic, intelsat, seabirds, meters, unreliable, farmland, oceans, legitimize,
# Nearest to test: cellspacing, wedged, parlay, elihu, deviated, tout, monoclonal, retainer,
# Nearest to pressure: smithers, allocation, achieve, dividend, elman, vegetation, magnets, caltrans,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2363 0.0504 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2208 0.0494 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2307 0.0491 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1358 0.0495 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2086 0.0493 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1842 0.0493 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1966 0.0493 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1844 0.0496 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2218 0.0496 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1843 0.0495 sec/batch
# Nearest to states: suharto, reservations, constituency, united, militaries, insurrections, malay, rica,
# Nearest to will: homeostatic, ergonomics, prosecution, carbamazepine, humiliate, servants, gags, lawful,
# Nearest to united: electoral, mayors, parole, states, celebrities, schuman, secession, roc,
# Nearest to d: luba, leonhard, ricci, ennius, hone, seymour, loftus, yuri,
# Nearest to system: tydings, leeway, paypal, cost, carausius, patently, slideshow, desktop,
# Nearest to who: child, tarawa, longterm, stralsund, philharmonic, ombudsman, yoda, famers,
# Nearest to was: sightseeing, dina, launching, gingold, limousine, niven, pastimes, aerospace,
# Nearest to more: unintentional, tend, curriculum, vaz, illa, utilizing, simplification, quenched,
# Nearest to stage: farce, upright, skimmed, meadow, takers, apertures, redstone, best,
# Nearest to shows: transporting, ride, better, carinae, dendrites, shopping, beg, neck,
# Nearest to older: householder, average, age, households, females, household, median, interment,
# Nearest to defense: counter, citizen, contested, hugo, stairways, tracer, rushmore, incident,
# Nearest to grand: uyghur, acton, impressive, jacobins, raum, wintered, catcher, coanda,
# Nearest to ocean: atlantic, intelsat, seabirds, noncombatant, meters, kq, unreliable, ifrcs,
# Nearest to test: wedged, cellspacing, parlay, monoclonal, transporting, tout, elihu, deviated,
# Nearest to pressure: allocation, smithers, achieve, dividend, vegetation, elman, magnets, energy,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1946 0.0502 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2191 0.0496 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1595 0.0496 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1555 0.0495 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1507 0.0495 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1894 0.0495 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1773 0.0496 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1493 0.0495 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1261 0.0494 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1718 0.0496 sec/batch
# Nearest to states: reservations, suharto, militaries, constituency, united, insurrections, rica, malay,
# Nearest to will: homeostatic, ergonomics, prosecution, humiliate, requiring, removes, lawful, ramps,
# Nearest to united: electoral, mayors, states, parole, secession, schuman, celebrities, kingdom,
# Nearest to d: ricci, leonhard, luba, yoakam, seymour, hone, ennius, fiji,
# Nearest to system: tydings, leeway, slideshow, regulate, preamplifier, patently, arbitral, unix,
# Nearest to who: child, tarawa, philharmonic, stralsund, longterm, magistrate, famers, yoda,
# Nearest to was: sightseeing, dina, gretchen, silverberg, limousine, gingold, daimyo, gediminas,
# Nearest to more: unintentional, tend, curriculum, vaz, viceroyalty, newcomers, quenched, lifeforms,
# Nearest to stage: farce, skimmed, upright, takers, redstone, meadow, apertures, warbeck,
# Nearest to shows: transporting, ride, carinae, better, shopping, dendrites, beg, neck,
# Nearest to older: householder, average, age, households, median, females, household, size,
# Nearest to defense: counter, citizen, hugo, contested, stairways, tracer, recipients, incident,
# Nearest to grand: uyghur, raum, acton, wintered, catcher, impressive, jacobins, coanda,
# Nearest to ocean: intelsat, atlantic, relay, ifrcs, noncombatant, oceans, unreliable, seabirds,
# Nearest to test: wedged, cellspacing, parlay, monoclonal, elihu, deviated, tout, hobbyists,
# Nearest to pressure: allocation, achieve, smithers, dividend, vegetation, elman, synergies, magnets,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1898 0.0503 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.2031 0.0495 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1822 0.0496 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1824 0.0499 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1472 0.0493 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1623 0.0493 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1576 0.0495 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1439 0.0497 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1998 0.0497 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2359 0.0494 sec/batch
# Nearest to states: united, suharto, reservations, militaries, insurrections, constituency, malay, rica,
# Nearest to will: homeostatic, ergonomics, lawful, prosecution, suetonius, nabonidus, servants, ticker,
# Nearest to united: electoral, mayors, states, parole, secession, celebrities, schuman, gazi,
# Nearest to d: ricci, leonhard, luba, b, physicist, zariski, andr, composer,
# Nearest to system: tydings, leeway, patently, regulate, slideshow, carausius, arbitral, dorset,
# Nearest to who: child, of, magistrate, stralsund, tarawa, philharmonic, baal, confessors,
# Nearest to was: dina, sightseeing, gretchen, launching, gingold, gediminas, daimyo, limousine,
# Nearest to more: unintentional, tend, vaz, curriculum, viceroyalty, quenched, illa, newcomers,
# Nearest to stage: farce, skimmed, warbeck, upright, redstone, best, apertures, takers,
# Nearest to shows: ride, transporting, carinae, better, shopping, beg, abrahams, dendrites,
# Nearest to older: householder, average, households, age, median, females, household, size,
# Nearest to defense: counter, citizen, hugo, contested, stairways, tracer, incident, recipients,
# Nearest to grand: uyghur, raum, wintered, catcher, acton, coanda, jacobins, guile,
# Nearest to ocean: intelsat, atlantic, ifrcs, relay, regencies, oceans, scandinavia, noncombatant,
# Nearest to test: cellspacing, parlay, monoclonal, wedged, elihu, tout, hobbyists, deviated,
# Nearest to pressure: smithers, allocation, achieve, dividend, synergies, vegetation, elman, curfew,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2466 0.0502 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1496 0.0494 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1432 0.0496 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1269 0.0496 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0425 0.0497 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1384 0.0493 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1439 0.0498 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1327 0.0497 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1575 0.0081 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1256 0.0495 sec/batch
# Nearest to states: suharto, united, reservations, militaries, rica, insurrections, constituency, malay,
# Nearest to will: ergonomics, homeostatic, redshifted, prosecution, lawful, requiring, carbamazepine, ticker,
# Nearest to united: electoral, mayors, states, celebrities, parole, schuman, armando, gazi,
# Nearest to d: leonhard, ricci, luba, b, hendrik, physicist, svenska, zariski,
# Nearest to system: tydings, leeway, unix, patently, slideshow, regulate, paypal, rhotic,
# Nearest to who: child, magistrate, tarawa, diaz, stralsund, philharmonic, longterm, confessors,
# Nearest to was: dina, sightseeing, launching, limousine, gingold, meanwhile, gediminas, aerospace,
# Nearest to more: unintentional, tend, quenched, vaz, illa, curriculum, nouns, simplification,
# Nearest to stage: skimmed, farce, meadow, apertures, takers, best, upright, discontent,
# Nearest to shows: ride, transporting, better, shopping, carinae, beg, dendrites, abrahams,
# Nearest to older: householder, average, age, households, median, household, size, females,
# Nearest to defense: counter, citizen, hugo, contested, stairways, recipients, tracer, rushmore,
# Nearest to grand: uyghur, wintered, acton, raum, jacobins, guile, impressive, coanda,
# Nearest to ocean: intelsat, atlantic, ifrcs, relay, oceans, unreliable, regencies, seabirds,
# Nearest to test: cellspacing, monoclonal, parlay, wedged, ban, elihu, compromised, effectiveness,
# Nearest to pressure: smithers, allocation, achieve, dividend, synergies, vegetation, elman, magnets,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0715 0.0504 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0686 0.0494 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0899 0.0494 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0358 0.0495 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0786 0.0496 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0463 0.0495 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0810 0.0495 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1128 0.0499 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1231 0.0495 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0380 0.0495 sec/batch
# Nearest to states: united, reservations, suharto, militaries, rica, insurrections, constituency, alabama,
# Nearest to will: ergonomics, homeostatic, lawful, clove, prosecution, servants, redshifted, suetonius,
# Nearest to united: electoral, states, mayors, parole, celebrities, kingdom, schuman, aleutians,
# Nearest to d: ricci, leonhard, luba, svenska, ennius, physicist, fiji, hendrik,
# Nearest to system: tydings, leeway, unix, paypal, patently, preamplifier, desktop, slideshow,
# Nearest to who: child, magistrate, tarawa, longterm, of, confessors, demobilization, baal,
# Nearest to was: dina, sightseeing, launching, gingold, ashore, aerospace, limousine, microsoft,
# Nearest to more: unintentional, tend, illa, quenched, newcomers, vaz, mpv, evolved,
# Nearest to stage: meadow, skimmed, farce, apertures, upright, best, discontent, takers,
# Nearest to shows: ride, shopping, carinae, better, transporting, beg, dendrites, abrahams,
# Nearest to older: householder, households, median, average, age, household, size, females,
# Nearest to defense: counter, hugo, citizen, tracer, contested, stairways, recipients, rushmore,
# Nearest to grand: uyghur, raum, wintered, impressive, acton, guile, coanda, jacobins,
# Nearest to ocean: intelsat, atlantic, ifrcs, unreliable, relay, oceans, shevardnadze, bos,
# Nearest to test: cellspacing, parlay, monoclonal, wedged, ban, compromised, elihu, effectiveness,
# Nearest to pressure: achieve, smithers, allocation, dividend, synergies, curfew, vegetation, prognosis,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0348 0.0502 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0202 0.0495 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0368 0.0496 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0486 0.0495 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0457 0.0493 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0294 0.0496 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0692 0.0495 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1039 0.0495 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0421 0.0500 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0462 0.0496 sec/batch
# Nearest to states: united, reservations, militaries, suharto, rica, chancery, insurrections, constituency,
# Nearest to will: homeostatic, ergonomics, redshifted, clove, ticker, synodic, disabling, servants,
# Nearest to united: states, electoral, mayors, celebrities, kingdom, schuman, parole, aleutians,
# Nearest to d: ricci, luba, leonhard, ennius, svenska, asymptotic, hydroxy, hone,
# Nearest to system: tydings, patently, leeway, ribose, preamplifier, regulate, unix, universal,
# Nearest to who: child, longterm, of, magistrate, confessors, tarawa, philharmonic, baal,
# Nearest to was: sightseeing, dina, gingold, rumoured, niven, aerospace, moonset, daimyo,
# Nearest to more: unintentional, tend, quenched, newcomers, mpv, evolved, farmers, manageable,
# Nearest to stage: meadow, farce, apertures, skimmed, best, warbeck, upright, takers,
# Nearest to shows: shopping, better, carinae, ride, transporting, dendrites, abrahams, beg,
# Nearest to older: householder, households, median, average, household, age, size, females,
# Nearest to defense: counter, hugo, citizen, contested, recipients, stairways, tracer, rushmore,
# Nearest to grand: uyghur, raum, wintered, acton, coanda, dme, jacobins, guile,
# Nearest to ocean: intelsat, atlantic, oceans, ifrcs, relay, cauca, unreliable, shevardnadze,
# Nearest to test: cellspacing, parlay, ban, monoclonal, compromised, hobbyists, wedged, effectiveness,
# Nearest to pressure: achieve, smithers, allocation, synergies, vegetation, dividend, curfew, elman,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0391 0.0504 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0767 0.0496 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0612 0.0494 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0655 0.0496 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0747 0.0495 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0575 0.0496 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0542 0.0496 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0883 0.0497 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0776 0.0498 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0683 0.0495 sec/batch
# Nearest to states: united, suharto, militaries, reservations, rica, insurrections, alabama, lake,
# Nearest to will: ergonomics, homeostatic, ticker, redshifted, disabling, misdirection, synodic, breaks,
# Nearest to united: states, electoral, mayors, kingdom, celebrities, schuman, parole, aleutians,
# Nearest to d: luba, ricci, ennius, leonhard, svenska, andr, asymptotic, hydroxy,
# Nearest to system: tydings, leeway, patently, universal, herald, unix, regulate, dorset,
# Nearest to who: child, of, tarawa, longterm, baal, magistrate, partner, philharmonic,
# Nearest to was: dina, sightseeing, reorganisation, rumoured, gingold, aerospace, vigorously, ashore,
# Nearest to more: unintentional, tend, newcomers, illa, evolved, farmers, quenched, wrc,
# Nearest to stage: meadow, farce, skimmed, apertures, discontent, best, warbeck, takers,
# Nearest to shows: carinae, shopping, ride, transporting, dendrites, humbucker, better, abrahams,
# Nearest to older: householder, age, households, median, average, household, size, females,
# Nearest to defense: counter, hugo, recipients, citizen, stairways, tracer, contested, rushmore,
# Nearest to grand: uyghur, raum, coanda, wintered, dme, guile, acton, impressive,
# Nearest to ocean: intelsat, atlantic, ifrcs, relay, oceans, cauca, regencies, shevardnadze,
# Nearest to test: cellspacing, parlay, monoclonal, ban, wedged, elihu, compromised, tout,
# Nearest to pressure: achieve, smithers, allocation, synergies, curfew, dividend, vegetation, elman,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0633 0.0504 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0049 0.0498 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0656 0.0493 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0451 0.0496 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0995 0.0494 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1276 0.0494 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1134 0.0496 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0561 0.0493 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0483 0.0495 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0820 0.0492 sec/batch
# Nearest to states: united, suharto, militaries, reservations, rica, alabama, insurrections, lake,
# Nearest to will: ergonomics, homeostatic, ticker, indeterminacy, synodic, redshifted, transmeta, clove,
# Nearest to united: states, electoral, celebrities, schuman, aleutians, parole, kingdom, mayors,
# Nearest to d: luba, ricci, ennius, svenska, andr, leonhard, hendrik, storch,
# Nearest to system: tydings, leeway, patently, safeguards, universal, ribose, democracies, preamplifier,
# Nearest to who: child, philharmonic, longterm, diaz, inari, baal, of, tarawa,
# Nearest to was: rumoured, dina, sightseeing, gingold, vigorously, aerospace, nakano, introducing,
# Nearest to more: tend, unintentional, quenched, evolved, illa, newcomers, farmers, invention,
# Nearest to stage: farce, discontent, meadow, skimmed, best, apertures, takers, warbeck,
# Nearest to shows: carinae, shopping, ride, dendrites, transporting, better, humbucker, beg,
# Nearest to older: householder, age, households, median, size, household, average, females,
# Nearest to defense: counter, hugo, recipients, stairways, citizen, tracer, contested, rushmore,
# Nearest to grand: uyghur, coanda, raum, guile, dme, duc, wintered, abolished,
# Nearest to ocean: intelsat, atlantic, oceans, ifrcs, relay, cauca, regencies, shevardnadze,
# Nearest to test: ban, cellspacing, monoclonal, parlay, elihu, effectiveness, wedged, tout,
# Nearest to pressure: achieve, smithers, allocation, synergies, dividend, curfew, elman, vegetation,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9969 0.0501 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0277 0.0496 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0282 0.0496 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0248 0.0498 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0691 0.0494 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0268 0.0438 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0064 0.0496 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9944 0.0495 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0205 0.0494 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9695 0.0496 sec/batch
# Nearest to states: united, reservations, suharto, lake, militaries, alabama, insurrections, chancery,
# Nearest to will: ergonomics, homeostatic, ticker, synodic, parishioners, misdirection, clove, indeterminacy,
# Nearest to united: states, celebrities, electoral, schuman, aleutians, kingdom, mayors, parole,
# Nearest to d: ricci, luba, physicist, earl, hendrik, andr, leonhard, hoppe,
# Nearest to system: tydings, patently, unix, macos, leeway, universal, ribose, athlon,
# Nearest to who: child, baal, of, longterm, diaz, inari, confessors, fedayeen,
# Nearest to was: rumoured, dina, gingold, ashore, moonset, daimyo, sightseeing, limousine,
# Nearest to more: tend, unintentional, quenched, evolved, mpv, illa, newcomers, invention,
# Nearest to stage: meadow, apertures, discontent, best, takers, skimmed, redstone, farce,
# Nearest to shows: shopping, carinae, ride, transporting, better, dendrites, membership, banda,
# Nearest to older: householder, age, size, median, households, household, average, females,
# Nearest to defense: counter, recipients, hugo, stairways, tracer, rushmore, citizen, contested,
# Nearest to grand: uyghur, coanda, raum, guile, duc, acton, wintered, abolished,
# Nearest to ocean: intelsat, atlantic, ifrcs, oceans, unreliable, cauca, relay, shevardnadze,
# Nearest to test: ban, cellspacing, monoclonal, parlay, elihu, tout, effectiveness, retainer,
# Nearest to pressure: achieve, allocation, smithers, synergies, dividend, elman, curfew, vegetation,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0025 0.0501 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9123 0.0494 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0272 0.0498 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0125 0.0495 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0288 0.0494 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0065 0.0493 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8993 0.0495 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9458 0.0496 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9531 0.0496 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9741 0.0495 sec/batch
# Nearest to states: united, suharto, reservations, militaries, rica, lake, illegal, chancery,
# Nearest to will: ergonomics, homeostatic, ticker, synodic, indeterminacy, breaks, parishioners, disabling,
# Nearest to united: states, kingdom, electoral, schuman, celebrities, mayors, aleutians, parole,
# Nearest to d: luba, ricci, ennius, svenska, hydroxy, storch, leonhard, hendrik,
# Nearest to system: tydings, patently, leeway, universal, safeguards, democracies, ribose, dorset,
# Nearest to who: child, longterm, fedayeen, baal, partner, philharmonic, tarawa, of,
# Nearest to was: rumoured, sightseeing, moonset, dina, ashore, gingold, vigorously, continued,
# Nearest to more: tend, unintentional, mpv, farmers, evolved, quenched, newcomers, disruptions,
# Nearest to stage: meadow, discontent, farce, best, takers, apertures, redstone, skimmed,
# Nearest to shows: shopping, carinae, ride, transporting, dendrites, banda, membership, humbucker,
# Nearest to older: householder, age, households, size, median, household, average, females,
# Nearest to defense: counter, hugo, recipients, stairways, tracer, rushmore, contested, citizen,
# Nearest to grand: uyghur, coanda, guile, raum, dme, duc, abolished, impressive,
# Nearest to ocean: intelsat, atlantic, cauca, ifrcs, oceans, relay, shevardnadze, eutelsat,
# Nearest to test: ban, monoclonal, cellspacing, parlay, elihu, tout, effectiveness, deviated,
# Nearest to pressure: achieve, smithers, allocation, synergies, dividend, curfew, colloidal, elman,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0102 0.0505 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9999 0.0495 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9598 0.0495 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0188 0.0495 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0076 0.0494 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9603 0.0495 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9906 0.0495 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9886 0.0495 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9743 0.0493 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9756 0.0495 sec/batch
# Nearest to states: united, reservations, suharto, militaries, chancery, illegal, tente, rubin,
# Nearest to will: ergonomics, homeostatic, ticker, synodic, breaks, disabling, redshifted, indeterminacy,
# Nearest to united: states, kingdom, celebrities, schuman, electoral, aleutians, mayors, parole,
# Nearest to d: ricci, luba, andr, svenska, ennius, physicist, storch, hendrik,
# Nearest to system: tydings, universal, patently, safeguards, leeway, ribose, macos, preamplifier,
# Nearest to who: child, of, partner, longterm, demobilization, baal, confessors, diaz,
# Nearest to was: rumoured, dina, moonset, sightseeing, vigorously, nakano, continued, scottsdale,
# Nearest to more: unintentional, tend, mpv, evolved, unattractive, quenched, strung, newcomers,
# Nearest to stage: meadow, best, farce, discontent, takers, ballets, redstone, apertures,
# Nearest to shows: shopping, carinae, dendrites, ride, transporting, banda, membership, humbucker,
# Nearest to older: householder, age, size, median, households, household, average, families,
# Nearest to defense: counter, recipients, hugo, rushmore, stairways, tracer, microbiologist, citizen,
# Nearest to grand: coanda, raum, uyghur, dme, guile, impressive, duc, piranha,
# Nearest to ocean: intelsat, cauca, ifrcs, atlantic, oceans, shevardnadze, eutelsat, unreliable,
# Nearest to test: ban, elihu, monoclonal, cellspacing, parlay, deviated, tout, effectiveness,
# Nearest to pressure: achieve, smithers, synergies, allocation, colloidal, galvanometer, dividend, vegetation,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9984 0.0503 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9706 0.0494 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9957 0.0496 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9679 0.0494 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0015 0.0499 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9841 0.0495 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9870 0.0496 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9718 0.0494 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9823 0.0494 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0310 0.0496 sec/batch
# Nearest to states: united, suharto, militaries, reservations, illegal, chancery, insurrections, tente,
# Nearest to will: ergonomics, homeostatic, ticker, untainted, breaks, synodic, offers, parishioners,
# Nearest to united: states, kingdom, celebrities, schuman, electoral, aleutians, talia, parole,
# Nearest to d: luba, ricci, storch, ennius, andr, svenska, hydroxy, ph,
# Nearest to system: tydings, leeway, universal, safeguards, dorset, patently, democracies, arbitral,
# Nearest to who: child, of, partner, baal, longterm, fedayeen, confessors, descent,
# Nearest to was: rumoured, dina, moonset, reorganisation, vigorously, ashore, sightseeing, nakano,
# Nearest to more: tend, evolved, unintentional, mpv, quenched, unattractive, invention, newcomers,
# Nearest to stage: meadow, discontent, farce, best, ballets, skimmed, apertures, takers,
# ...
# Nearest to system: safeguards, beos, systems, convinced, mimeograph, replace, marshallese, pledged,
# Nearest to who: untaet, child, of, partner, given, however, longterm, descent,
# Nearest to was: in, became, as, been, rumoured, its, he, first,
# Nearest to more: than, tend, smaller, evolved, reasons, expensive, among, many,
# Nearest to stage: papp, takers, best, warbeck, farce, discontent, brave, complicit,
# Nearest to shows: encoded, banda, diagram, fertilize, dendrites, show, ascended, saiyan,
# Nearest to older: age, size, median, householder, household, families, households, average,
# Nearest to defense: counter, stairways, tracer, microbiologist, rushmore, hugo, gion, ntfs,
# Nearest to grand: dme, prix, geo, raum, coanda, piranha, cc, midgard,
# Nearest to ocean: atlantic, eutelsat, oceans, intelsat, legitimize, winds, shevardnadze, cauca,
# Nearest to test: ban, tests, elihu, cellspacing, monoclonal, species, batsman, bodyline,
# Nearest to pressure: galvanometer, smithers, achieve, curfew, colloidal, deputies, volume, vegetation,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8379 0.0507 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8304 0.0497 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8843 0.0500 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8429 0.0499 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8804 0.0498 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9025 0.0499 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8630 0.0499 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8368 0.0500 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8800 0.0500 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8502 0.0501 sec/batch
# Nearest to states: united, americans, union, chancery, kingdom, iban, nations, recipients,
# Nearest to will: ticker, tithe, homeostatic, synodic, breaks, redshifted, pattern, misdirection,
# Nearest to united: states, kingdom, celebrities, cnd, surratt, talia, recognition, thoroughbreds,
# Nearest to d: ph, luba, storch, meshech, whitespace, svenska, solubility, hydroxy,
# Nearest to system: safeguards, pledged, replace, beos, mimeograph, pasts, by, systems,
# Nearest to who: untaet, of, partner, child, given, descent, however, longterm,
# Nearest to was: in, became, he, rumoured, been, later, as, the,
# Nearest to more: than, tend, smaller, evolved, of, among, the, in,
# Nearest to stage: takers, papp, warbeck, best, farce, redstone, rulebase, brave,
# Nearest to shows: diagram, banda, encoded, fertilize, ascended, dendrites, saiyan, show,
# Nearest to older: size, age, householder, median, household, families, average, households,
# Nearest to defense: counter, stairways, microbiologist, tracer, rushmore, gion, hugo, mohamed,
# Nearest to grand: prix, dme, coanda, geo, piranha, sepp, cc, cougars,
# Nearest to ocean: atlantic, eutelsat, intelsat, oceans, winds, shevardnadze, legitimize, popularized,
# Nearest to test: ban, tests, elihu, monoclonal, species, cellspacing, kotzebue, triton,
# Nearest to pressure: smithers, galvanometer, resolves, achieve, vegetation, curfew, overcrowding, liutprand,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8687 0.0506 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8678 0.0496 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8410 0.0498 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8326 0.0499 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8798 0.0498 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8236 0.0500 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9706 0.0497 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9104 0.0498 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9233 0.0498 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8193 0.0498 sec/batch
# Nearest to states: united, americans, union, nations, chancery, recipients, iban, kingdom,
# Nearest to will: ticker, homeostatic, synodic, tithe, pattern, redshifted, have, breaks,
# Nearest to united: states, kingdom, celebrities, cnd, nations, recognition, thoroughbreds, talia,
# Nearest to d: ph, meshech, luba, storch, whitespace, svenska, hydroxy, ennius,
# Nearest to system: safeguards, marshallese, pledged, systems, pasts, beos, monopolies, replace,
# Nearest to who: untaet, given, descent, of, partner, child, however, inari,
# Nearest to was: he, became, in, later, did, rumoured, had, been,
# Nearest to more: than, tend, evolved, smaller, many, this, most, in,
# Nearest to stage: takers, papp, warbeck, best, complicit, discontent, performing, donny,
# Nearest to shows: banda, diagram, ascended, fertilize, encoded, dendrites, geertz, ride,
# Nearest to older: size, age, householder, median, household, families, share, households,
# Nearest to defense: counter, stairways, tracer, microbiologist, rushmore, militaries, mohamed, ntfs,
# Nearest to grand: prix, dme, coanda, piranha, cougars, geo, cc, sepp,
# Nearest to ocean: atlantic, oceans, intelsat, eutelsat, shevardnadze, winds, legitimize, popularized,
# Nearest to test: ban, elihu, tests, monoclonal, species, cellspacing, reports, kotzebue,
# Nearest to pressure: galvanometer, smithers, achieve, liutprand, overcrowding, slams, generalissimo, volume,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7778 0.0505 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8572 0.0499 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7972 0.0497 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8721 0.0500 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8354 0.0500 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8538 0.0497 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9009 0.0241 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8307 0.0499 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8399 0.0500 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8493 0.0502 sec/batch
# Nearest to states: united, americans, union, chancery, iban, recipients, nations, kingdom,
# Nearest to will: ticker, homeostatic, synodic, redshifted, tithe, have, pattern, parishioners,
# Nearest to united: states, kingdom, celebrities, cnd, talia, thoroughbreds, ecclesiastica, aleutians,
# Nearest to d: meshech, ph, luba, b, storch, physicist, inglis, american,
# Nearest to system: safeguards, systems, marshallese, beos, replace, dundas, convinced, pasts,
# Nearest to who: untaet, given, child, of, partner, descent, born, however,
# Nearest to was: he, became, in, the, been, and, had, later,
# Nearest to more: than, tend, smaller, evolved, many, all, be, among,
# Nearest to stage: takers, papp, complicit, best, redstone, performing, discontent, skimmed,
# Nearest to shows: banda, diagram, theatrical, encoded, dendrites, show, fertilize, ascended,
# Nearest to older: size, age, householder, household, median, share, families, households,
# Nearest to defense: counter, stairways, tracer, rushmore, armed, microbiologist, rium, ntfs,
# Nearest to grand: prix, coanda, cc, dme, slam, raum, berengar, sepp,
# Nearest to ocean: atlantic, oceans, winds, shevardnadze, eutelsat, intelsat, legitimize, cauca,
# Nearest to test: tests, ban, elihu, species, monoclonal, testing, rocket, batsman,
# Nearest to pressure: galvanometer, achieve, smithers, liutprand, overcrowding, generalissimo, deputies, allocation,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8415 0.0506 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8064 0.0499 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8414 0.0499 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7689 0.0500 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8515 0.0498 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8486 0.0502 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8813 0.0498 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7721 0.0500 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8343 0.0496 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8083 0.0497 sec/batch
# Nearest to states: united, americans, union, kingdom, nations, iban, chancery, recipients,
# Nearest to will: ticker, synodic, redshifted, homeostatic, tithe, breaks, ergonomics, parishioners,
# Nearest to united: states, kingdom, cnd, thoroughbreds, celebrities, talia, u, surratt,
# Nearest to d: luba, meshech, ph, whitespace, storch, hydroxy, svenska, hendrik,
# Nearest to system: safeguards, systems, beos, marshallese, replace, entirely, convinced, universal,
# Nearest to who: untaet, given, partner, child, of, descent, born, a,
# Nearest to was: became, in, as, been, he, later, were, had,
# Nearest to more: than, smaller, tend, evolved, many, all, be, is,
# Nearest to stage: papp, takers, brave, best, complicit, skimmed, discontent, warbeck,
# Nearest to shows: banda, diagram, encoded, fertilize, theatrical, ascended, show, dendrites,
# Nearest to older: size, age, householder, median, household, share, families, versus,
# Nearest to defense: counter, stairways, tracer, microbiologist, armed, ntfs, rushmore, delphic,
# Nearest to grand: prix, dme, coanda, slam, cc, geo, piranha, raum,
# Nearest to ocean: atlantic, oceans, legitimize, shevardnadze, winds, eutelsat, intelsat, cauca,
# Nearest to test: tests, ban, elihu, testing, species, monoclonal, cellspacing, batsman,
# Nearest to pressure: galvanometer, deputies, resolves, generalissimo, overcrowding, liutprand, traore, smithers,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7669 0.0504 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8177 0.0498 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8577 0.0500 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8244 0.0499 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8178 0.0502 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8858 0.0500 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8482 0.0504 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8339 0.0499 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8176 0.0500 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8398 0.0498 sec/batch
# Nearest to states: united, americans, union, nations, kingdom, iban, chancery, recipients,
# Nearest to will: ticker, tithe, homeostatic, synodic, redshifted, that, breaks, pattern,
# Nearest to united: states, kingdom, cnd, celebrities, talia, thoroughbreds, status, surratt,
# Nearest to d: ph, meshech, luba, whitespace, storch, hydroxy, svenska, hone,
# Nearest to system: safeguards, systems, by, beos, replace, pledged, marshallese, convinced,
# Nearest to who: untaet, of, partner, given, child, a, however, descent,
# Nearest to was: became, in, as, he, rumoured, first, been, and,
# Nearest to more: than, smaller, tend, many, be, evolved, all, is,
# Nearest to stage: papp, takers, best, donny, brave, warbeck, ballets, complicit,
# Nearest to shows: banda, diagram, fertilize, encoded, theatrical, dendrites, circle, ride,
# Nearest to older: age, size, median, household, householder, share, families, versus,
# Nearest to defense: counter, stairways, tracer, microbiologist, ntfs, gion, militaries, conditioning,
# Nearest to grand: prix, dme, coanda, geo, slam, cc, piranha, midgard,
# Nearest to ocean: oceans, atlantic, legitimize, winds, intelsat, eutelsat, shevardnadze, cauca,
# Nearest to test: tests, ban, elihu, testing, species, electronic, monoclonal, nuclear,
# Nearest to pressure: galvanometer, smithers, overcrowding, resolves, allocation, deputies, achieve, vegetation,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8886 0.0510 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8384 0.0501 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7916 0.0500 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8466 0.0495 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8650 0.0498 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8164 0.0499 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8279 0.0498 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8650 0.0496 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8196 0.0496 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8342 0.0495 sec/batch
# Nearest to states: united, americans, union, nations, chancery, recipients, iban, illegal,
# Nearest to will: ticker, tithe, homeostatic, that, pattern, redshifted, have, offers,
# Nearest to united: states, kingdom, cnd, ecclesiastica, celebrities, nations, recognition, surratt,
# Nearest to d: ph, luba, meshech, whitespace, storch, svenska, hydroxy, rawlings,
# Nearest to system: safeguards, systems, replace, beos, by, pledged, entirely, marshallese,
# Nearest to who: untaet, of, given, child, a, inari, partner, descent,
# Nearest to was: became, in, as, been, rumoured, first, later, and,
# Nearest to more: than, smaller, tend, many, is, be, this, in,
# Nearest to stage: papp, takers, brave, warbeck, best, bills, skimmed, rulebase,
# Nearest to shows: diagram, banda, encoded, fertilize, geertz, ascended, dendrites, television,
# Nearest to older: age, size, household, householder, median, share, families, versus,
# Nearest to defense: counter, stairways, tracer, microbiologist, ntfs, militaries, armed, gion,
# Nearest to grand: prix, dme, cc, coanda, slam, piranha, raum, geo,
# Nearest to ocean: atlantic, oceans, legitimize, eutelsat, winds, shevardnadze, intelsat, cauca,
# Nearest to test: tests, ban, elihu, testing, species, monoclonal, reports, electronic,
# Nearest to pressure: galvanometer, liutprand, overcrowding, resolves, smithers, generalissimo, deputies, vegetation,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8697 0.0509 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8129 0.0496 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9262 0.0500 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8985 0.0501 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8906 0.0496 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8730 0.0495 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7850 0.0497 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8530 0.0500 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7218 0.0495 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8629 0.0499 sec/batch
# Nearest to states: united, americans, union, nations, recipients, chancery, kingdom, geography,
# Nearest to will: ticker, tithe, homeostatic, have, redshifted, pattern, that, synodic,
# Nearest to united: states, kingdom, cnd, nations, thoroughbreds, u, recognition, surratt,
# Nearest to d: ph, meshech, b, luba, physicist, whitespace, svenska, storch,
# Nearest to system: systems, safeguards, beos, entirely, by, monopolies, replace, convinced,
# Nearest to who: untaet, of, given, child, a, partner, inari, descent,
# Nearest to was: became, in, he, later, been, first, and, rumoured,
# Nearest to more: than, smaller, tend, many, most, is, all, be,
# Nearest to stage: takers, papp, best, complicit, farce, brave, warbeck, skimmed,
# Nearest to shows: diagram, banda, encoded, fertilize, change, ascended, vowels, ride,
# Nearest to older: age, size, household, median, householder, share, families, average,
# Nearest to defense: counter, stairways, armed, ntfs, microbiologist, tracer, gion, militaries,
# Nearest to grand: prix, slam, dme, walras, coanda, cc, piranha, geo,
# Nearest to ocean: atlantic, oceans, winds, legitimize, eutelsat, shevardnadze, intelsat, cauca,
# Nearest to test: ban, tests, elihu, testing, species, monoclonal, nuclear, cremated,
# Nearest to pressure: liutprand, galvanometer, generalissimo, overcrowding, deputies, resolves, smithers, traore,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8613 0.0504 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8405 0.0497 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
